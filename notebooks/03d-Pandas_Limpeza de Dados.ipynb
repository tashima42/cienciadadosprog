# %% [markdown]
# # Limpeza de Dados
#
# Os processos de limpeza e preparação de dados são muito importantes. Dados limpos, completos e organizados tornam as análises mais fáceis e confiáveis. Abaixo descrevemos alguns dos principais mecanismos para tratar dados que tenham algum problema.
#
# Execute cada célula de código abaixo para ver o resultado.

# %% [markdown]
# ## Leitura e análise inicial dos dados

# %%
#importação de bibliotecas
import pandas as pd

# lê o arquivo CSV
df = pd.read_csv('../data/aluguel-com-erros.csv')

# %% [markdown]
# O primeiro passo ao se analisar dados desconhecidos é visualizar algumas linhas de dados:

# %%
df.head(10)
# Out:
#    codigo                        endereco  quartos suite area  vaga aluguel  \
# 0      34    Rua Desembargador Westphalen        2     0   90     0     900
# 1     167               Rua Jose Loureiro        2     0   64     0     650
# 2    6784               Rua Jose Loureiro        2     0   81     0    1100
# 3      82              Rua Lourenço Pinto        2     0   50     0    1350
# 4    2970              Rua Lourenço Pinto        2     0   63     0    1300
# 5   34197           Alameda Doutor Muricy        2     0   80     1     900
# 6    5072           Alameda Doutor Muricy        2     0   84     0    1100
# 7     469                             NaN        1     0   30     0     550
# 8      24     R. Desembargador Westphalen        1     0   60     1     800
# 9      74  Avenida Visconde de Guarapuava        2     1  132     1    1800
#
#   condominio      data
# 0        371  11/10/17
# 1        428  15/07/17
# 2       1100  23/08/17
# 3        300  19/09/17
# 4        300  05/08/17
# 5        410  23/10/17
# 6        382  02/09/17
# 7        210  03/07/17
# 8        120  30/09/17
# 9        520  12/10/17

# %% [markdown]
# O método `info` é útil para vermos quais colunas do DataFrame tiveram seus tipos de dados corretamente identificados pelo Pandas. No caso abaixo já é possível identificar alguns problemas. As colunas *quartos, suite, area, aluguel e condomínio* foram interpretadas como objetos genéricos enquanto deveriam ser numéricas. A coluna *data* deveria ser do tipo `datetype`.
#
# O método `info` também nos informa quantos valores cada coluna tem. Veja abaixo que a coluna *endereço* tem apenas 19 valores.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   codigo      20 non-null     int64
#  1   endereco    19 non-null     object
#  2   quartos     20 non-null     int64
#  3   suite       20 non-null     object
#  4   area        20 non-null     object
#  5   vaga        20 non-null     int64
#  6   aluguel     20 non-null     object
#  7   condominio  20 non-null     object
#  8   data        20 non-null     object
# dtypes: int64(3), object(6)
# memory usage: 1.5+ KB

# %% [markdown]
# ## Localizando e tratando valores inválidos

# %% [markdown]
# Se você quer eliminar as linhas com valores nulos em uma determinada coluna, basta usar o `.isna()` especificando a coluna.

# %%
df_sem_nulos = df[df['endereco'].isna() == False]

df_sem_nulos
# Out:
#     codigo                        endereco  quartos suite area  vaga aluguel  \
# 0       34    Rua Desembargador Westphalen        2     0   90     0     900
# 1      167               Rua Jose Loureiro        2     0   64     0     650
# 2     6784               Rua Jose Loureiro        2     0   81     0    1100
# 3       82              Rua Lourenço Pinto        2     0   50     0    1350
# 4     2970              Rua Lourenço Pinto        2     0   63     0    1300
# 5    34197           Alameda Doutor Muricy        2     0   80     1     900
# 6     5072           Alameda Doutor Muricy        2     0   84     0    1100
# 8       24     R. Desembargador Westphalen        1     0   60     1     800
# 9       74  Avenida Visconde de Guarapuava        2     1  132     1    1800
# 10    9850  Avenida Visconde de Guarapuava        1     0   64     1     600
# 11   82343        Avenida Sete de Setembro        1     0   45     0     750
# 12   20802        Avenida Sete de Setembro        1     0   47     0     600
# 13     568                Rua Alferes Poli        1     0   43     0     600
# 14  294579                Av. Silva Jardim        1     0   36     0     550
# 15   59375            Avenida Silva Jardim        1     0   33     0     560
# 16      80    Rua Desembargador Westphalen        1     0   80     1     900
# 17   66490    Rua Desembargador Westphalen        1     0   80     1    1100
# 18    2381                 Rua Rockefeller        2     0   54     0     900
# 19   44803                 Rua Rockefeller        2     ?    ?     1       ?
#
#    condominio        data
# 0         371    11/10/17
# 1         428    15/07/17
# 2        1100    23/08/17
# 3         300    19/09/17
# 4         300    05/08/17
# 5         410    23/10/17
# 6         382    02/09/17
# 8         120    30/09/17
# 9         520    12/10/17
# 10        326    15/07/17
# 11        420  janeiro 17
# 12        405    27/07/17
# 13        330    12/08/17
# 14        350    01/10/17
# 15        305    11/09/17
# 16        350    12/08/17
# 17        350    29/08/17
# 18        240    19/09/17
# 19          ?    19/07/17

# %% [markdown]
# Podemos usar o método `fillna` para substituir os valores em branco por um valor definido, neste caso a *String* "Desconhecido". Após a substituição não há mais linhas com valores em branco.

# %%
df['endereco'] = df['endereco'].fillna("Desconhecido")

df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [codigo, endereco, quartos, suite, area, vaga, aluguel, condominio, data]
# Index: []

# %% [markdown]
# Podemos também fazer substituições de partes das *strings* no DataFrame. Por exemplo, podemos padronizar ruas e avenidas com as abreviações R. e Av. O código abaixo faz isto:

# %%
df['endereco'] = df['endereco'].str.replace('Rua', 'R.')
df['endereco'] = df['endereco'].str.replace('Avenida', 'Av.')

df.head()
# Out:
#    codigo                     endereco  quartos suite area  vaga aluguel  \
# 0      34  R. Desembargador Westphalen        2     0   90     0     900
# 1     167             R. Jose Loureiro        2     0   64     0     650
# 2    6784             R. Jose Loureiro        2     0   81     0    1100
# 3      82            R. Lourenço Pinto        2     0   50     0    1350
# 4    2970            R. Lourenço Pinto        2     0   63     0    1300
#
#   condominio      data
# 0        371  11/10/17
# 1        428  15/07/17
# 2       1100  23/08/17
# 3        300  19/09/17
# 4        300  05/08/17

# %% [markdown]
# Ainda não sabemos por que diversas colunas numéricas foram identificadas com o tipo genérico *object*. Uma forma de averiguar é listar todos os valores não repetidos de uma coluna. O método `unique` é útil neste caso. Abaixo podemos ver que a coluna *aluguel* contém uma ou mais interrogações (?) entre os valores.

# %%
df['aluguel'].unique()
# Out:
# array(['900', '650', '1100', '1350', '1300', '550', '800', '1800', '600',
#        '750', '560', '?'], dtype=object)

# %% [markdown]
# Vamos então exibir todas as linhas com interrogações em alguma coluna. O comando abaixo identificou que a linha de índice 19 contém vários valores representados com uma interrogação.

# %%
df[df['aluguel'] == '?']
# Out:
#     codigo        endereco  quartos suite area  vaga aluguel condominio  \
# 19   44803  R. Rockefeller        2     ?    ?     1       ?          ?
#
#         data
# 19  19/07/17

# %% [markdown]
# Como a linha identificada acima tem muitos valores inválidos, podemos decidir retirá-la do DataFrame. Para isso, usamos o método `drop`. Perceba que a linha não aparece mais no DataFrame.

# %%
df = df.drop(19)

df
# Out:
#     codigo                     endereco  quartos suite area  vaga aluguel  \
# 0       34  R. Desembargador Westphalen        2     0   90     0     900
# 1      167             R. Jose Loureiro        2     0   64     0     650
# 2     6784             R. Jose Loureiro        2     0   81     0    1100
# 3       82            R. Lourenço Pinto        2     0   50     0    1350
# 4     2970            R. Lourenço Pinto        2     0   63     0    1300
# 5    34197        Alameda Doutor Muricy        2     0   80     1     900
# 6     5072        Alameda Doutor Muricy        2     0   84     0    1100
# 7      469                 Desconhecido        1     0   30     0     550
# 8       24  R. Desembargador Westphalen        1     0   60     1     800
# 9       74   Av. Visconde de Guarapuava        2     1  132     1    1800
# 10    9850   Av. Visconde de Guarapuava        1     0   64     1     600
# 11   82343         Av. Sete de Setembro        1     0   45     0     750
# 12   20802         Av. Sete de Setembro        1     0   47     0     600
# 13     568              R. Alferes Poli        1     0   43     0     600
# 14  294579             Av. Silva Jardim        1     0   36     0     550
# 15   59375             Av. Silva Jardim        1     0   33     0     560
# 16      80  R. Desembargador Westphalen        1     0   80     1     900
# 17   66490  R. Desembargador Westphalen        1     0   80     1    1100
# 18    2381               R. Rockefeller        2     0   54     0     900
#
#    condominio        data
# 0         371    11/10/17
# 1         428    15/07/17
# 2        1100    23/08/17
# 3         300    19/09/17
# 4         300    05/08/17
# 5         410    23/10/17
# 6         382    02/09/17
# 7         210    03/07/17
# 8         120    30/09/17
# 9         520    12/10/17
# 10        326    15/07/17
# 11        420  janeiro 17
# 12        405    27/07/17
# 13        330    12/08/17
# 14        350    01/10/17
# 15        305    11/09/17
# 16        350    12/08/17
# 17        350    29/08/17
# 18        240    19/09/17

# %% [markdown]
# ## Conversão de tipos

# %% [markdown]
# Como pode ser visto pela execução do método `info` abaixo, as colunas ainda possuem tipos incorretos. Precisamos então fazer a conversão manual dos tipos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 0 to 18
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   codigo      19 non-null     int64
#  1   endereco    19 non-null     object
#  2   quartos     19 non-null     int64
#  3   suite       19 non-null     object
#  4   area        19 non-null     object
#  5   vaga        19 non-null     int64
#  6   aluguel     19 non-null     object
#  7   condominio  19 non-null     object
#  8   data        19 non-null     object
# dtypes: int64(3), object(6)
# memory usage: 1.5+ KB

# %% [markdown]
# Para converter as colunas para os tipos adequados, usamos o método `astype`. Podemos tanto aplicar a uma coluna por vez ou em várias colunas representadas por um dicionário. O código abaixo exemplifica as duas abordagens:

# %%
df['suite'] = df['suite'].astype(int)

df = df.astype({'area': int, 'aluguel': float, 'condominio': float})

# %% [markdown]
# Para uma coluna com datas, precisamos usar um comando diferente, o `to_datetime`. Ao executar o comando abaixo obtemos um erro informando que há um valor de data contendo 'janeiro 17', que não pode ser interpretado pelo método.

# %%
df['data'] = pd.to_datetime(df['data'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2186         try:
# -> 2187             values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2188             # If tzaware, these values represent unix timestamps, so we
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-2d9e064dc6af> in <module>
# ----> 1 df['data'] = pd.to_datetime(df['data'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     885             result = arg.map(cache_array)
#     886         else:
# --> 887             values = convert_listlike(arg._values, format)
#     888             result = arg._constructor(values, index=arg.index, name=arg.name)
#     889     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     406         errors=errors,
#     407         require_iso8601=require_iso8601,
# --> 408         allow_object=True,
#     409     )
#     410
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2191             return values.view("i8"), tz_parsed
#    2192         except (ValueError, TypeError):
# -> 2193             raise err
#    2194
#    2195     if tz_parsed is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2180             yearfirst=yearfirst,
#    2181             require_iso8601=require_iso8601,
# -> 2182             allow_mixed=allow_mixed,
#    2183         )
#    2184         result = result.reshape(data.shape, order=order)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib._array_to_datetime_object()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib._array_to_datetime_object()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/anaconda3/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1356         return parser(parserinfo).parse(timestr, **kwargs)
#    1357     else:
# -> 1358         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1359
#    1360
#
# ~/anaconda3/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     647
#     648         if res is None:
# --> 649             raise ValueError("Unknown string format:", timestr)
#     650
#     651         if len(res) == 0:
#
# ValueError: ('Unknown string format:', 'janeiro 17')

# %% [markdown]
# Abaixo substituimos o valor com problema e com isso conseguimos converter corretamente a coluna.

# %%
df['data'] = df['data'].str.replace('janeiro 17', '01/01/17')

df['data'] = pd.to_datetime(df['data'], format='%d/%m/%y')

# %% [markdown]
# Agora podemos conferir os tipos e verificar que estão todos corretos:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 0 to 18
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   codigo      19 non-null     int64
#  1   endereco    19 non-null     object
#  2   quartos     19 non-null     int64
#  3   suite       19 non-null     int64
#  4   area        19 non-null     int64
#  5   vaga        19 non-null     int64
#  6   aluguel     19 non-null     float64
#  7   condominio  19 non-null     float64
#  8   data        19 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(5), object(1)
# memory usage: 1.5+ KB

# %% [markdown]
# Com todos os tipos convertidos corretamente, podemos aplicar funções estatísticas e exibir corretamente os valores em gráficos como mostrado abaixo:

# %%
print('Média do aluguel: ', df['aluguel'].mean())

df.set_index('data')['aluguel'].plot()
# Out:
# Média do aluguel:  895.2631578947369
# <AxesSubplot:xlabel='data'>

# %% [markdown]
# ## Identificando outliers

# %% [markdown]
# Outliers são valores fora da faixa esperada para uma observação. Um forma conveniente de identificar outliers é usando BoxPlots. Abaixo podemos perceber que existem dois valores de condomínio fora do que seria esperado (mostrados como círculos abaixo e acima da caixa).

# %%
df[['aluguel', 'condominio']].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outra forma de identificar outliers é calcular os *z-scores* para uma variável. O z-score fornece informação sobre o quão inesperado um valor é considerando os demais valores presentes. Abaixo calculamos os z-scores para a variável condomínio. Veja que um valor 'inesperado' é o 120 com z-score -1.3, indicando que é um valor mais baixo que o esperado. O outro outlier é o de condomínio 1100 com z-score 3.7 indicando que está muito acima do esperado. Em geral valores de z-score abaixo de -3 e acima de +3 são fortes candidados a serem outliers.

# %%
df['condominio_zscore'] = (df['condominio'] - df['condominio'].mean())/df['condominio'].std()

df.sort_values('condominio_zscore')
# Out:
#     codigo                     endereco  quartos  suite  area  vaga  aluguel  \
# 8       24  R. Desembargador Westphalen        1      0    60     1    800.0
# 7      469                 Desconhecido        1      0    30     0    550.0
# 18    2381               R. Rockefeller        2      0    54     0    900.0
# 3       82            R. Lourenço Pinto        2      0    50     0   1350.0
# 4     2970            R. Lourenço Pinto        2      0    63     0   1300.0
# 15   59375             Av. Silva Jardim        1      0    33     0    560.0
# 10    9850   Av. Visconde de Guarapuava        1      0    64     1    600.0
# 13     568              R. Alferes Poli        1      0    43     0    600.0
# 16      80  R. Desembargador Westphalen        1      0    80     1    900.0
# 14  294579             Av. Silva Jardim        1      0    36     0    550.0
# 17   66490  R. Desembargador Westphalen        1      0    80     1   1100.0
# 0       34  R. Desembargador Westphalen        2      0    90     0    900.0
# 6     5072        Alameda Doutor Muricy        2      0    84     0   1100.0
# 12   20802         Av. Sete de Setembro        1      0    47     0    600.0
# 5    34197        Alameda Doutor Muricy        2      0    80     1    900.0
# 11   82343         Av. Sete de Setembro        1      0    45     0    750.0
# 1      167             R. Jose Loureiro        2      0    64     0    650.0
# 9       74   Av. Visconde de Guarapuava        2      1   132     1   1800.0
# 2     6784             R. Jose Loureiro        2      0    81     0   1100.0
#
#     condominio       data  condominio_zscore
# 8        120.0 2017-09-30          -1.330867
# 7        210.0 2017-07-03          -0.869903
# 18       240.0 2017-09-19          -0.716248
# 3        300.0 2017-09-19          -0.408938
# 4        300.0 2017-08-05          -0.408938
# 15       305.0 2017-09-11          -0.383329
# 10       326.0 2017-07-15          -0.275770
# 13       330.0 2017-08-12          -0.255283
# 16       350.0 2017-08-12          -0.152846
# 14       350.0 2017-10-01          -0.152846
# 17       350.0 2017-08-29          -0.152846
# 0        371.0 2017-10-11          -0.045288
# 6        382.0 2017-09-02           0.011052
# 12       405.0 2017-07-27           0.128854
# 5        410.0 2017-10-23           0.154464
# 11       420.0 2017-01-01           0.205682
# 1        428.0 2017-07-15           0.246657
# 9        520.0 2017-10-12           0.717865
# 2       1100.0 2017-08-23           3.688527

# %% [markdown]
# Uma possibilidade para eliminar o valor que está muito acima seria excluir a linha que o contém. O problema disso é que perderíamos todos os dados da linha, que inclui dados aparentemente corretos. Uma forma de manter os dados corretos e ao mesmo tempo minimizar a influência do valor incorreto é substituir o valor incorreto pela média dos demais valores para a variável, como fazemos abaixo. Veja que agora o valor de condomínio para a linha problemática é 379.84.

# %%
df.loc[2, 'condominio'] = df['condominio'].mean()

df
# Out:
#     codigo                     endereco  quartos  suite  area  vaga  aluguel  \
# 0       34  R. Desembargador Westphalen        2      0    90     0    900.0
# 1      167             R. Jose Loureiro        2      0    64     0    650.0
# 2     6784             R. Jose Loureiro        2      0    81     0   1100.0
# 3       82            R. Lourenço Pinto        2      0    50     0   1350.0
# 4     2970            R. Lourenço Pinto        2      0    63     0   1300.0
# 5    34197        Alameda Doutor Muricy        2      0    80     1    900.0
# 6     5072        Alameda Doutor Muricy        2      0    84     0   1100.0
# 7      469                 Desconhecido        1      0    30     0    550.0
# 8       24  R. Desembargador Westphalen        1      0    60     1    800.0
# 9       74   Av. Visconde de Guarapuava        2      1   132     1   1800.0
# 10    9850   Av. Visconde de Guarapuava        1      0    64     1    600.0
# 11   82343         Av. Sete de Setembro        1      0    45     0    750.0
# 12   20802         Av. Sete de Setembro        1      0    47     0    600.0
# 13     568              R. Alferes Poli        1      0    43     0    600.0
# 14  294579             Av. Silva Jardim        1      0    36     0    550.0
# 15   59375             Av. Silva Jardim        1      0    33     0    560.0
# 16      80  R. Desembargador Westphalen        1      0    80     1    900.0
# 17   66490  R. Desembargador Westphalen        1      0    80     1   1100.0
# 18    2381               R. Rockefeller        2      0    54     0    900.0
#
#     condominio       data  condominio_zscore
# 0   371.000000 2017-10-11          -0.045288
# 1   428.000000 2017-07-15           0.246657
# 2   379.842105 2017-08-23           3.688527
# 3   300.000000 2017-09-19          -0.408938
# 4   300.000000 2017-08-05          -0.408938
# 5   410.000000 2017-10-23           0.154464
# 6   382.000000 2017-09-02           0.011052
# 7   210.000000 2017-07-03          -0.869903
# 8   120.000000 2017-09-30          -1.330867
# 9   520.000000 2017-10-12           0.717865
# 10  326.000000 2017-07-15          -0.275770
# 11  420.000000 2017-01-01           0.205682
# 12  405.000000 2017-07-27           0.128854
# 13  330.000000 2017-08-12          -0.255283
# 14  350.000000 2017-10-01          -0.152846
# 15  305.000000 2017-09-11          -0.383329
# 16  350.000000 2017-08-12          -0.152846
# 17  350.000000 2017-08-29          -0.152846
# 18  240.000000 2017-09-19          -0.716248

# %% [markdown]
# ## Escrevendo os dados limpos no disco
#
# Para salvar os dados limpos em um arquivo, usamos o método `to_csv`, como no exemplo abaixo:

# %%
df.to_csv('../data/aluguel-limpo.csv', index=False)
