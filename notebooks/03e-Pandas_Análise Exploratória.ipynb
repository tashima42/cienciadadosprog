# %% [markdown]
# # Análise Exploratória
#
# A Análise Exploratória é uma fase importante de uma tarefa de Ciência de Dados. É nesta fase que buscamos entender os dados com os seguintes objetivos:
#
# - Identificar padrões iniciais
# - Formular perguntas de pesquisa e hipóteses
# - Identificar dados incompletos ou não confiáveis
#
# Para atingir os objetivos, em geral usa-se uma combinação de análises estatísticas com uma grande ênfase em geração e interpretação de gráficos.

# %% [markdown]
# ## Leitura e análise inicial dos dados

# %%
# Importação de Bibliotecas
import pandas as pd

# %matplotlib inline

# lê o arquivo CSV
df = pd.read_csv('../data/aluguel.csv')

# %% [markdown]
# O primeiro passo ao se analisar dados desconhecidos é visualizar algumas linhas de dados:

# %%
df.head(10)
# Out:
#    codigo                        endereco  quartos  suite  area  vaga  \
# 0      34    Rua Desembargador Westphalen        2      0    90     0
# 1     167               Rua Jose Loureiro        2      0    64     0
# 2    6784               Rua Jose Loureiro        2      0    81     0
# 3      82              Rua Lourenço Pinto        2      0    50     0
# 4    2970              Rua Lourenço Pinto        2      0    63     0
# 5   34197           Alameda Doutor Muricy        2      0    80     1
# 6    5072           Alameda Doutor Muricy        2      0    84     0
# 7     469    Rua Desembargador Westphalen        1      0    30     0
# 8      24    Rua Desembargador Westphalen        1      0    60     1
# 9      74  Avenida Visconde de Guarapuava        2      1   132     1
#
#    aluguel  condominio      data
# 0      900         371  11/10/17
# 1      650         428  15/07/17
# 2     1100         400  23/08/17
# 3     1350         300  19/09/17
# 4     1300         300  05/08/17
# 5      900         410  23/10/17
# 6     1100         382  02/09/17
# 7      550         210  03/07/17
# 8      800         120  30/09/17
# 9     1800         520  12/10/17

# %% [markdown]
# O método `describe` é útil para se ter uma idéia de estatísticas básicas para as variáveis numéricas. Por exemplo, abaixo podemos ver que a média dos valores de aluguel é 898 enquanto a mediana (50 percentil) é 900.

# %%
df.describe()
# Out:
#               codigo    quartos      suite        area      vaga      aluguel  \
# count      20.000000  20.000000  20.000000   20.000000  20.00000    20.000000
# mean    31557.200000   1.500000   0.050000   64.650000   0.35000   898.000000
# std     67034.809578   0.512989   0.223607   24.303509   0.48936   326.102987
# min        24.000000   1.000000   0.000000   30.000000   0.00000   550.000000
# 25%       145.750000   1.000000   0.000000   46.500000   0.00000   600.000000
# 50%      4021.000000   1.500000   0.000000   63.500000   0.00000   900.000000
# 75%     36848.500000   2.000000   0.000000   80.000000   1.00000  1100.000000
# max    294579.000000   2.000000   1.000000  132.000000   1.00000  1800.000000
#
#        condominio
# count    20.00000
# mean    335.85000
# std      92.21558
# min     120.00000
# 25%     300.00000
# 50%     350.00000
# 75%     401.25000
# max     520.00000

# %% [markdown]
# ## Visualização da distribuição de variáveis

# %% [markdown]
# Visualizar as distribuições das variaveis nos ajuda a identificar os primeiros padrões. Abaixo exibimos os histogramas para `aluguel` e `condomínio`. É possivel ver que a maior concentração de apartamentos é de aluguéis entre 600 e 900. Há também uma concentração menor em aluguéis em torno de 1200. Já a distribuição dos condomínios é mais homogênea, com a maior parte dos valores por volta de 370.
#
# Faz sentido este comportamento? Aparentemente o condomínio não varia na mesma proporção do valor do aluguel. Ou seja, se um apartamento de 600 paga 300 de condomínio, não se espera que um apartamento de 1200 pague 600 de condomínio. Esta pode ser uma questão a se explorar em passos futuros das análises.

# %%
df['aluguel'].hist(bins=7)
# Out:
# <AxesSubplot:>

# %%
df['condominio'].hist(bins=7)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Podemos também exibir as distribuições usando KDEs:

# %%
df['aluguel'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['condominio'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Outra forma de visualizar a distribuição de variáveis é através de Box Plots. Abaixo exibimos uma gráfico para aluguéis e condomínios. Novamente, podemos perceber que a variação nos aluguéis é maior que nos condomínios. Nos condomínios podemos ver tambem um outlier (círculo abaixo da barra). Verifique os dados e identifique qual apartamento tem este valor de condomínio tão diferente.

# %%
df[['aluguel', 'condominio']].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Análise da correlação entre as variáveis

# %% [markdown]
# Para identificar associações entre as variáveis podemos utilizar diversas ferramentas estatísticas e visuais. Para calcular a correlação (Pearson) entre todos os pares de variáves, podemos usar o método `corr`. Abaixo podemos ver que a maior correlação está entre a área do apartamento e o aluguel. Isto significa que, aparentemente, o tamanho do apartamento é o que mais influencia no valor total.

# %%
df.corr()
# Out:
#               codigo   quartos     suite      area      vaga   aluguel  \
# codigo      1.000000 -0.335195 -0.110545 -0.324856 -0.104901 -0.300360
# quartos    -0.335195  1.000000  0.229416  0.542466 -0.104828  0.619797
# suite      -0.110545  0.229416  1.000000  0.652274  0.312641  0.651048
# area       -0.324856  0.542466  0.652274  1.000000  0.533035  0.748196
# vaga       -0.104901 -0.104828  0.312641  0.533035  1.000000  0.251974
# aluguel    -0.300360  0.619797  0.651048  0.748196  0.251974  1.000000
# condominio  0.070605  0.214173  0.470034  0.466627 -0.087415  0.302494
#
#             condominio
# codigo        0.070605
# quartos       0.214173
# suite         0.470034
# area          0.466627
# vaga         -0.087415
# aluguel       0.302494
# condominio    1.000000

# %% [markdown]
# Uma forma interessante de visualizar a matrix de correlações é usar um Heatmap. No caso abaixo usamos cores azuis para identificar as correlações maiores e cores vermelhas para as menores.

# %%
df_corr = df.corr()
df_corr = df_corr.style.background_gradient(cmap='RdBu')
df_corr
# Out:
# <style  type="text/css" >
# #T_380af_row0_col0,#T_380af_row1_col1,#T_380af_row2_col2,#T_380af_row3_col3,#T_380af_row4_col4,#T_380af_row5_col5,#T_380af_row6_col6{
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }#T_380af_row0_col1,#T_380af_row0_col2,#T_380af_row0_col3,#T_380af_row0_col4,#T_380af_row0_col5,#T_380af_row1_col0,#T_380af_row1_col4,#T_380af_row4_col6{
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }#T_380af_row0_col6{
#             background-color:  #c2383a;
#             color:  #f1f1f1;
#         }#T_380af_row1_col2{
#             background-color:  #f5a886;
#             color:  #000000;
#         }#T_380af_row1_col3{
#             background-color:  #aed3e6;
#             color:  #000000;
#         }#T_380af_row1_col5{
#             background-color:  #8ac0db;
#             color:  #000000;
#         }#T_380af_row1_col6{
#             background-color:  #ee9677;
#             color:  #000000;
#         }#T_380af_row2_col0{
#             background-color:  #cb4942;
#             color:  #f1f1f1;
#         }#T_380af_row2_col1,#T_380af_row4_col5{
#             background-color:  #fce2d2;
#             color:  #000000;
#         }#T_380af_row2_col3{
#             background-color:  #75b2d4;
#             color:  #000000;
#         }#T_380af_row2_col4{
#             background-color:  #fbceb7;
#             color:  #000000;
#         }#T_380af_row2_col5{
#             background-color:  #78b4d5;
#             color:  #000000;
#         }#T_380af_row2_col6{
#             background-color:  #f2f5f6;
#             color:  #000000;
#         }#T_380af_row3_col0{
#             background-color:  #6a011f;
#             color:  #f1f1f1;
#         }#T_380af_row3_col1{
#             background-color:  #acd2e5;
#             color:  #000000;
#         }#T_380af_row3_col2,#T_380af_row5_col2{
#             background-color:  #9bc9e0;
#             color:  #000000;
#         }#T_380af_row3_col4{
#             background-color:  #dae9f2;
#             color:  #000000;
#         }#T_380af_row3_col5{
#             background-color:  #408fc1;
#             color:  #000000;
#         }#T_380af_row3_col6{
#             background-color:  #f3f5f6;
#             color:  #000000;
#         }#T_380af_row4_col0,#T_380af_row4_col1{
#             background-color:  #cc4c44;
#             color:  #f1f1f1;
#         }#T_380af_row4_col2{
#             background-color:  #fbd0b9;
#             color:  #000000;
#         }#T_380af_row4_col3{
#             background-color:  #b3d6e8;
#             color:  #000000;
#         }#T_380af_row5_col0{
#             background-color:  #790622;
#             color:  #f1f1f1;
#         }#T_380af_row5_col1{
#             background-color:  #84bcd9;
#             color:  #000000;
#         }#T_380af_row5_col3{
#             background-color:  #3f8ec0;
#             color:  #000000;
#         }#T_380af_row5_col4{
#             background-color:  #f6b191;
#             color:  #000000;
#         }#T_380af_row5_col6{
#             background-color:  #f9c4a9;
#             color:  #000000;
#         }#T_380af_row6_col0{
#             background-color:  #f4a683;
#             color:  #000000;
#         }#T_380af_row6_col1{
#             background-color:  #fcdecd;
#             color:  #000000;
#         }#T_380af_row6_col2{
#             background-color:  #eff3f5;
#             color:  #000000;
#         }#T_380af_row6_col3{
#             background-color:  #d2e6f0;
#             color:  #000000;
#         }#T_380af_row6_col4{
#             background-color:  #730421;
#             color:  #f1f1f1;
#         }#T_380af_row6_col5{
#             background-color:  #f9ede5;
#             color:  #000000;
#         }</style><table id="T_380af_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >codigo</th>        <th class="col_heading level0 col1" >quartos</th>        <th class="col_heading level0 col2" >suite</th>        <th class="col_heading level0 col3" >area</th>        <th class="col_heading level0 col4" >vaga</th>        <th class="col_heading level0 col5" >aluguel</th>        <th class="col_heading level0 col6" >condominio</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_380af_level0_row0" class="row_heading level0 row0" >codigo</th>
#                         <td id="T_380af_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_380af_row0_col1" class="data row0 col1" >-0.335195</td>
#                         <td id="T_380af_row0_col2" class="data row0 col2" >-0.110545</td>
#                         <td id="T_380af_row0_col3" class="data row0 col3" >-0.324856</td>
#                         <td id="T_380af_row0_col4" class="data row0 col4" >-0.104901</td>
#                         <td id="T_380af_row0_col5" class="data row0 col5" >-0.300360</td>
#                         <td id="T_380af_row0_col6" class="data row0 col6" >0.070605</td>
#             </tr>
#             <tr>
#                         <th id="T_380af_level0_row1" class="row_heading level0 row1" >quartos</th>
#                         <td id="T_380af_row1_col0" class="data row1 col0" >-0.335195</td>
#                         <td id="T_380af_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_380af_row1_col2" class="data row1 col2" >0.229416</td>
#                         <td id="T_380af_row1_col3" class="data row1 col3" >0.542466</td>
#                         <td id="T_380af_row1_col4" class="data row1 col4" >-0.104828</td>
#                         <td id="T_380af_row1_col5" class="data row1 col5" >0.619797</td>
#                         <td id="T_380af_row1_col6" class="data row1 col6" >0.214173</td>
#             </tr>
#             <tr>
#                         <th id="T_380af_level0_row2" class="row_heading level0 row2" >suite</th>
#                         <td id="T_380af_row2_col0" class="data row2 col0" >-0.110545</td>
#                         <td id="T_380af_row2_col1" class="data row2 col1" >0.229416</td>
#                         <td id="T_380af_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_380af_row2_col3" class="data row2 col3" >0.652274</td>
#                         <td id="T_380af_row2_col4" class="data row2 col4" >0.312641</td>
#                         <td id="T_380af_row2_col5" class="data row2 col5" >0.651048</td>
#                         <td id="T_380af_row2_col6" class="data row2 col6" >0.470034</td>
#             </tr>
#             <tr>
#                         <th id="T_380af_level0_row3" class="row_heading level0 row3" >area</th>
#                         <td id="T_380af_row3_col0" class="data row3 col0" >-0.324856</td>
#                         <td id="T_380af_row3_col1" class="data row3 col1" >0.542466</td>
#                         <td id="T_380af_row3_col2" class="data row3 col2" >0.652274</td>
#                         <td id="T_380af_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_380af_row3_col4" class="data row3 col4" >0.533035</td>
#                         <td id="T_380af_row3_col5" class="data row3 col5" >0.748196</td>
#                         <td id="T_380af_row3_col6" class="data row3 col6" >0.466627</td>
#             </tr>
#             <tr>
#                         <th id="T_380af_level0_row4" class="row_heading level0 row4" >vaga</th>
#                         <td id="T_380af_row4_col0" class="data row4 col0" >-0.104901</td>
#                         <td id="T_380af_row4_col1" class="data row4 col1" >-0.104828</td>
#                         <td id="T_380af_row4_col2" class="data row4 col2" >0.312641</td>
#                         <td id="T_380af_row4_col3" class="data row4 col3" >0.533035</td>
#                         <td id="T_380af_row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_380af_row4_col5" class="data row4 col5" >0.251974</td>
#                         <td id="T_380af_row4_col6" class="data row4 col6" >-0.087415</td>
#             </tr>
#             <tr>
#                         <th id="T_380af_level0_row5" class="row_heading level0 row5" >aluguel</th>
#                         <t

# %% [markdown]
# A correlação é uma boa medida de associação entre variáveis, mas ela não oferece detalhes sobre a distribuição ou sobre a presença de outliers. Para se ter uma ideia melhor das associações, é interessante visualizar os dados no plano cartesiano. Para isto podemos construir uma matriz com as visualizações dos pontos para todas as combinações de variáveis. Abaixo fazemos isto para área, aluguel e condomínio. Veja que entre aluguel e área há realmente uma tendência de associação (maior concentração de pontos próximos à diagonal).

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(df[['area','aluguel','condominio']], figsize=(10, 10), diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='area', ylabel='area'>,
#         <AxesSubplot:xlabel='aluguel', ylabel='area'>,
#         <AxesSubplot:xlabel='condominio', ylabel='area'>],
#        [<AxesSubplot:xlabel='area', ylabel='aluguel'>,
#         <AxesSubplot:xlabel='aluguel', ylabel='aluguel'>,
#         <AxesSubplot:xlabel='condominio', ylabel='aluguel'>],
#        [<AxesSubplot:xlabel='area', ylabel='condominio'>,
#         <AxesSubplot:xlabel='aluguel', ylabel='condominio'>,
#         <AxesSubplot:xlabel='condominio', ylabel='condominio'>]],
#       dtype=object)

# %% [markdown]
# Podemos também construir um gráfico isolando apenas duas variáveis para explorar com mais detalhes:

# %%
df.plot.scatter(x='area', y='aluguel')
# Out:
# <AxesSubplot:xlabel='area', ylabel='aluguel'>

# %% [markdown]
# Uma visualização útil para comparar mais de duas variáveis é o Parallel Coordinates. Abaixo plotamos linhas em azul representando apartamentos com 2 quartos e linhas verdes para os de 1 quarto. É possivel observar que apartamentos de dois quartos tendem a ter área e valor de aluguel mais altos. Já o valor do condomínio não demonstra uma superioridade tão marcante para os apartamentos de 2 quartos.

# %%
from pandas.plotting import parallel_coordinates

parallel_coordinates(df[['area','aluguel','condominio', 'quartos']], 'quartos', colormap='winter')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Comparando proporções

# %% [markdown]
# Podemos usar gráficos de pizza para comparar proporções de partes. Abaixo calculamos o total de ofertas de apartamentos por número de vagas e exibimos o resultado em um gráfico de pizza.

# %%
df_vagas = df.groupby('vaga').size().rename('Total vagas')
df_vagas
# Out:
# vaga
# 0    13
# 1     7
# Name: Total vagas, dtype: int64

# %%
df_vagas.plot.pie()
# Out:
# <AxesSubplot:ylabel='Total vagas'>

# %% [markdown]
# Poderíamos também ter usado um gráfico de barras:

# %%
df_vagas.plot.bar()
# Out:
# <AxesSubplot:xlabel='vaga'>

# %% [markdown]
# Gráficos de barras também são úteis para comparar valores individuais, como abaixo. É fácil identificar quais são os apartamentos com valores maiores e menores.

# %%
df.plot.barh(x='codigo', y=['aluguel', 'condominio'])
# Out:
# <AxesSubplot:ylabel='codigo'>

# %% [markdown]
# ## Analisando tendências de crescimento

# %% [markdown]
# Quando analisamos dados sequenciais (por exemplo dados temporais), é interessante plotar linhas que demonstrem a tendência de crescimento ao longo do tempo. Abaixo exibimos os valores de apartamentos de acordo com a data de registro da oferta. Esta não é uma boa visualização porque ela não deixa claro se a variação é referente ao período ou a fatores específicos do apartamento (como área ou número de quartos).

# %%
# converte coluna data para o tipo datetime
df['data'] = pd.to_datetime(df['data'], format='%d/%m/%y')

df.set_index('data').sort_index()[['aluguel', 'condominio']].plot()
# Out:
# <AxesSubplot:xlabel='data'>

# %% [markdown]
# Uma visualização temporal mais interessante pode ser obtida se calcularmos a média dos valores de aluguel para cada mês. Abaixo calculamos e exibimos os valores médios de aluguel e condomínio por mês. Agora sim podemos identificar que aparentemente há um aumento nos valores no mês de agosto.

# %%
periodo = df.data.dt.to_period("M")  # transforma datas em mês/ano

df.groupby(periodo)[['aluguel', 'condominio']].mean().plot()
# Out:
# <AxesSubplot:xlabel='data'>

# %% [markdown]
# ### Referências
#
# - Documentação do Pandas: [Visualization](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html)
