# %% [markdown]
# ## Descrição do dataset
#
# O conjunto de dados "Sistema E-Saude - Perfil de atendimento Odontológico nas Unidades Municipais de Saúde de Curitiba" reúne informações sobre atendimentos realizados por profissionais de odontologia em unidades de saúde. Esses dados mostram o perfil dos usuários atendidos, com informações demográficas, socioeconômicas e de saúde, além de detalhes sobre os procedimentos realizados.
#
# Este contjunto de dados pode ser encontrado no [Portal de Dados Abertos da Prefeitura de Curitiba](https://dadosabertos.curitiba.pr.gov.br/conjuntodado/detalhe?chave=afa9c22d-4fd7-407a-857b-1ab29fc305a3).

# %%
import pandas as pd

df = pd.read_csv('./2025-07-06_Sistema_E-Saude_Odontologico_-_Base_de_Dados.csv', sep=';', encoding='latin-1')

df
# Out:
#         Data do Atendimento   Data de Nascimento Sexo  \
# 0       01/03/2025 00:02:37  24/10/2001 00:00:00    F
# 1       01/03/2025 00:39:57  22/01/2003 00:00:00    F
# 2       01/03/2025 00:39:57  22/01/2003 00:00:00    F
# 3       01/03/2025 00:59:30  23/11/1962 00:00:00    M
# 4       01/03/2025 00:59:30  23/11/1962 00:00:00    M
# ...                     ...                  ...  ...
# 326165  06/05/2025 17:29:01  15/03/1951 00:00:00    M
# 326166  30/04/2025 10:14:45  25/02/1997 00:00:00    F
# 326167  06/03/2025 07:58:24  17/11/1993 00:00:00    F
# 326168  19/05/2025 15:05:15  09/08/1993 00:00:00    M
# 326169  23/04/2025 17:44:44  02/06/1998 00:00:00    M
#
#         Código do Tipo de Unidade Tipo de Unidade  Código da Unidade  \
# 0                               6    ODONTOLOGICO            2639467
# 1                               6    ODONTOLOGICO            2639467
# 2                               6    ODONTOLOGICO            2639467
# 3                               6    ODONTOLOGICO            2639467
# 4                               6    ODONTOLOGICO            2639467
# ...                           ...             ...                ...
# 326165                          6    ODONTOLOGICO              17108
# 326166                          6    ODONTOLOGICO              17094
# 326167                          6    ODONTOLOGICO              17329
# 326168                          6    ODONTOLOGICO              17051
# 326169                          6    ODONTOLOGICO              16926
#
#         Descrição da Unidade  Código do Procedimento  \
# 0             UPA FAZENDINHA               301060037
# 1             UPA FAZENDINHA               101020090
# 2             UPA FAZENDINHA               307020029
# 3             UPA FAZENDINHA               101020090
# 4             UPA FAZENDINHA               301060037
# ...                      ...                     ...
# 326165            UMS CAJURU               101020104
# 326166           UMS CAMARGO               101020104
# 326167      UMS VILA MACHADO               307030059
# 326168      UMS SOLITUDE PSF               101020104
# 326169  UMS SANTA FELICIDADE               101020074
#
#                                 Descrição do Procedimento  Código do CBO  ...  \
# 0               ATENDIMENTO DE URGENCIA EM ATENCAO BASICA         223208  ...
# 1               SELAMENTO PROVISORIO DE CAVIDADE DENTARIA         223208  ...
# 2         CURATIVO DE DEMORA C/ OU S/ PREPARO BIOMECANICO         223208  ...
# 3               SELAMENTO PROVISORIO DE CAVIDADE DENTARIA         223208  ...
# 4               ATENDIMENTO DE URGENCIA EM ATENCAO BASICA         223208  ...
# ...                                                   ...            ...  ...
# 326165                        ORIENTACAO DE HIGIENE BUCAL         322405  ...
# 326166                        ORIENTACAO DE HIGIENE BUCAL         322405  ...
# 326167  RASPAGEM ALISAMENTO E POLIMENTO SUPRAGENGIVAIS...         322405  ...
# 326168                        ORIENTACAO DE HIGIENE BUCAL         322425  ...
# 326169  APLICACAO TOPICA DE FLUOR (INDIVIDUAL POR SESSAO)         322405  ...
#
#        Grupo Comunitário     Meio de Comunicacao  Meio de Transporte  \
# 0                    NaN                     NaN                 NaN
# 1                 OUTROS         TELEVISAO,RADIO              ONIBUS
# 2                 OUTROS         TELEVISAO,RADIO              ONIBUS
# 3                 OUTROS         TELEVISAO,RADIO              ONIBUS
# 4                 OUTROS         TELEVISAO,RADIO              ONIBUS
# ...                  ...                     ...                 ...
# 326165     NAO PARTICIPA               TELEVISAO               CARRO
# 326166     NAO PARTICIPA  TELEVISAO,RADIO,OUTROS        ONIBUS,CARRO
# 326167     NAO PARTICIPA         TELEVISAO,RADIO        ONIBUS,CARRO
# 326168            OUTROS                   RADIO              ONIBUS
# 326169     NAO PARTICIPA  TELEVISAO,RADIO,OUTROS        ONIBUS,CARRO
#
#        Municício            Bairro  Nacionalidade  cod_usuario origem_usuario  \
# 0       CURITIBA  CAMPO DE SANTANA     Brasileira      2199063              1
# 1       CURITIBA      VISTA ALEGRE     Brasileira      3717342              1
# 2       CURITIBA      VISTA ALEGRE     Brasileira      3717342              1
# 3       CURITIBA          SAO BRAZ     Brasileira      4267263              1
# 4       CURITIBA          SAO BRAZ     Brasileira      4267263              1
# ...          ...               ...            ...          ...            ...
# 326165  CURITIBA            CAJURU     Brasileira        72343              1
# 326166  CURITIBA            CAJURU     Brasileira     12398062              1
# 326167  CURITIBA       PINHEIRINHO     Brasileira      1191391              1
# 326168  CURITIBA            CAJURU     Brasileira     12127039              1
# 326169  CURITIBA  SANTA FELICIDADE     Brasileira       982007              1
#
#        residente cod_profissional
# 0              1           122756
# 1              1           122756
# 2              1           122756
# 3              1           122756
# 4              1           122756
# ...          ...              ...
# 326165         1            41078
# 326166         1            41584
# 326167         1            41660
# 326168         1             2736
# 326169         1           128958
#
# [326170 rows x 42 columns]

# %% [markdown]
# ## Limpeza

# %%
print("O conjunto de dados antes da limpeza, possui", df.shape[0], "linhas")
# Out:
# O conjunto de dados antes da limpeza, possui 326170 linhas

# %% [markdown]
# Pela natureza do sistema de coleta de dados, algumas colunas não são válidas ou utilizadas para atendimentos odontológicos. Outras, são raramente preenchidas. Por esses motivos, colunas totalmente vazias ou com poucos valores não serão utilizadas.

# %%
df.isnull().sum()
# Out:
# Data do Atendimento                                  0
# Data de Nascimento                                   0
# Sexo                                                 0
# Código do Tipo de Unidade                            0
# Tipo de Unidade                                      0
# Código da Unidade                                    0
# Descrição da Unidade                                 0
# Código do Procedimento                               0
# Descrição do Procedimento                            0
# Código do CBO                                        0
# Descrição do CBO                                     0
# Código do CID                                   326170
# Descrição do CID                                326170
# Solicitação de Exames                                0
# Qtde Prescrita Farmácia Curitibana                   0
# Qtde Dispensada Farmácia Curitibana                  0
# Qtde de Medicamento Não Padronizado                  0
# Encaminhamento para Atendimento Especialista         0
# Área de Atuação                                 309099
# Desencadeou Internamento                             0
# Data do Internamento                            326170
# Estabelecimento Solicitante                     326170
# Estabelecimento Destino                         326170
# CID do Internamento                             326170
# Tratamento no Domicílio                          57703
# Abastecimento                                    58740
# Energia Elétrica                                     0
# Tipo de Habitação                                58171
# Destino Lixo                                     58665
# Fezes/Urina                                      59578
# Cômodos                                           7605
# Em Caso de Doença                                58301
# Grupo Comunitário                                60310
# Meio de Comunicacao                              58812
# Meio de Transporte                               58611
# Municício                                            0
# Bairro                                               0
# Nacionalidade                                        0
# cod_usuario                                          0
# origem_usuario                                       0
# residente                                            0
# cod_profissional                                     0
# dtype: int64

# %% [markdown]
# Apenas as colunas consideradas válidas para a análise foram mantidas, sendo elas:
# - Data do Atendimento
# - Data de Nascimento
# - Sexo
# - Descrição da Unidade
# - Descrição do Procedimento
# - Descrição do CBO
# - Energia Elétrica
# - Cômodos
# - Municício
# - Bairro
# - Nacionalidade
#
# Uma coluna adicional, "Idade", foi criada a partir da diferença entre a data do atendimento e a data de nascimento.
#
# Linhas com valores nulos e com número de cômodos considerados inválidos (acima de 20) foram removidas.

# %%
df = df.loc[:, ['Data do Atendimento', 'Data de Nascimento', 'Sexo', 'Descrição da Unidade', 'Descrição do Procedimento', 'Descrição do CBO', 'Energia Elétrica', 'Cômodos', 'Municício', 'Bairro', 'Nacionalidade']].copy()

df = df.copy()

# Remove linhas com NaN
df = df.dropna()

# %%
# Transformar em objetos datetime
df['Data do Atendimento'] = pd.to_datetime(df['Data do Atendimento'], format='%d/%m/%Y %H:%M:%S')
df['Data de Nascimento'] = pd.to_datetime(df['Data de Nascimento'], format='%d/%m/%Y %H:%M:%S')
df['Idade'] = (df['Data do Atendimento'] - df['Data de Nascimento']).dt.days // 365

# %%
# Transformar em booleanos
df['Energia Elétrica'] = df['Energia Elétrica'].map({'Nao': False, 'Sim': True})

# %%
# Transformar em integer
df['Cômodos'] = df['Cômodos'].astype(int)
# Limpeza de casas com mais de 20 comodos
df = df[df['Cômodos'] <= 20]

# %% [markdown]
# ## Análise Exploratória de Dados

# %% [markdown]
# Distribuição dos cômodos das casas dos pacientes:

# %%
df['Cômodos'].hist(bins=10)
# Out:
# <Axes: >

# %% [markdown]
# Distribuição de idade dos pacientes:

# %%
df['Idade'].hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# Número de atêndimentos de homens e mulheres:

# %%
df.groupby('Sexo').size().plot.bar()
# Out:
# <Axes: xlabel='Sexo'>

# %% [markdown]
# Unidades com mais atendimentos:

# %%
df.groupby('Descrição da Unidade').size().sort_values(ascending=False).head(5).plot.bar()
# Out:
# <Axes: xlabel='Descrição da Unidade'>

# %% [markdown]
# Bairros com mais atendimentos:

# %%
df.groupby('Bairro').size().sort_values(ascending=False).head(5).plot.bar()
# Out:
# <Axes: xlabel='Bairro'>

# %% [markdown]
# Procedimentos mais comuns:

# %%
df.groupby('Descrição do Procedimento').size().sort_values(ascending=False).head(5).plot.bar()
# Out:
# <Axes: xlabel='Descrição do Procedimento'>

# %% [markdown]
# Número de atendimentos em que os pacientes relataram ter energia elétrica:

# %%
df.groupby('Energia Elétrica').size().plot.bar()
# Out:
# <Axes: xlabel='Energia Elétrica'>

# %% [markdown]
# Distribuição da nacionalidade dos pacientes atendidos:

# %%
df.groupby('Nacionalidade').size().plot.bar()
# Out:
# <Axes: xlabel='Nacionalidade'>

# %% [markdown]
# ## Perguntas

# %% [markdown]
# 1. Quais os tipos de atendimentos mais comuns realizados pelos dentistas da rede municipal de saúde?
# 2. Os procedimentos variam de acordo com o sexo do paciente?
# 3. Existe correlação entre o número de cômodos da residência e o procedimento realizado?
# 4. Existe correlação entre ter energia elétrica e o bairro do paciente?
# 5. Existe correlação entre a idade do paciente e o tipo de procedimento realizado?
# 6. A nacionalidade do paciente influencia no número de cômodos da residência?
# 7. Qual a distribuição dos atendimentos ao longo dos meses?
